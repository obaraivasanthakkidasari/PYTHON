# %% [markdown]
# # MatplotLib Library

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
d={"Length":np.random.randn(500)}
df=pd.DataFrame(d)
df
# Out:
#        Length
# 0    0.460634
# 1   -0.168166
# 2    1.291671
# 3    1.322601
# 4    0.680064
# ..        ...
# 495  0.398548
# 496  0.219933
# 497  0.405642
# 498  0.046647
# 499 -0.078523
#
# [500 rows x 1 columns]

# %% [markdown]
# # Histogram

# %%
#Histogram
plt.hist(df['Length'])
plt.show()

# %%
plt.hist(df['Length']) #10bins for default.
plt.xlabel("Length") #set label for Xaxis
plt.ylabel("Count/Frequency") #set label for yaxis
plt.title("Histogram of Length")
plt.show()

# %%
plt.hist(df['Length'],bins=15)
plt.show()

# %%
#Horinzontal orientation 
plt.hist(df['Length'],orientation='horizontal')
plt.xlabel("count") #set label for Xaxis
plt.ylabel("Length") #set label for yaxis
plt.title("Histogram of Length")
plt.show()

# %% [markdown]
# # BOX PLOT

# %%
#Check for outlier

# %%
plt.boxplot(df['Length'])
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
#USE: LINEARITY DIRECTION STRENGTH

# %%
a=[1,2,0.4,9,7]
b=[1,3,0.7,4,9]
plt.scatter(a,b)
plt.show()

# %%
x=[1,2,0.4,9,7]
y=[1,3,0.7,4,9]
plt.scatter(x,y,color='red',marker='*')
plt.show()

# %%
x=[1,2,0.4,9,7]
y=[1,3,0.7,4,9]
plt.scatter(x,y,color='red')
plt.show()

# %% [markdown]
# # LINE PLOT

# %%
#X-AXIS VALUE PUT IN SEQUENCE

# %%
#SYNTAX:plt.plot(obarai)

# %%
#creating a chart of a singlelist

# %%
s=[16,12,11,10,1,8,4,17,9,11,15,14,13]
plt.plot(s)
plt.show()

# %%
#Creating a line char of single list

# %%
s=[1,2,3,4,5]
plt.plot(s)
plt.show()

# %%
s=[16,12,11,10,1,8,4,17,9,11,15,14,13]
plt.plot(s)
plt.show()

# %%
s=[1,2,13,4,5]
plt.plot(s)
plt.show()

# %%
plt.plot([16,12,11,10,1,8,4,17,9,11,15,14,13],color='green',linewidth=2.0)
plt.plot(s)
plt.show()

# %%
x= [1,20,13,45,25]
y=[100,150,42,76,85]
plt.plot(x,y)
plt.show()

# %%
x=np.arange(6)
y=x
z=x**2
e=x**3
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,z)

# %%
plt.plot(x,e)

# %%
plt.plot(x,y)
plt.plot(x,z)
plt.plot(x,e)
plt.show() #3 in single cell when x values are same

# %%
plt.plot(x,y, label='Linear')
plt.plot(x,z,label='quadratic')
plt.plot(x,e, label='cubic')
plt.legend()
plt.show() #legend means box

# %%
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]
plt.plot(days,max_t,label="max")
plt.plot(days,min_t,label="min")
plt.plot(days,avg_t,label="avg")
#set axis labels and chart titles
plt.xlabel('Days')
plt.ylabel('Temparature')
plt.title('weather')
plt.legend()
plt.show()

# %%
plt.plot([16,12,11,10,1,8,4,17,9,11,15,14,13],color='green')
plt.grid()
plt.text(8,16,'Lineplot')
plt.text(2,12,'Obarai')
plt.show() #grid means graph.

# %% [markdown]
# # SUBPLOT

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]
#plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.plot(x,y,color="green",marker="*",linestyle='dashed')
plt.title("line plot")
plt.subplot(2,2,2)
plt.scatter(x,y)
plt.title("Scatter plot")
plt.subplot(2,2,3)
plt.plot(x,y,linewidth=3)
plt.subplot(2,2,4)
plt.plot(x,y,color="green",marker="o",linestyle='dashed')
plt.title("line plot")
plt.show()

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]
#plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.plot(x,y,color="green",marker="*",linestyle='dashed')
plt.title("line plot")
plt.subplot(2,2,2)
plt.scatter(x,y)
plt.title("Scatter plot")
plt.subplot(2,2,3)
plt.plot(x,y,linewidth=3)
plt.subplot(2,2,4)
plt.plot(x,y,color="green",marker="o",linestyle='dashed')
plt.title("line plot")
plt.show()

# %% [markdown]
# # Pie Chart

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]
#plt.figure(figsize=(10,10))
plt.subplot(3,2,1)
plt.plot(x,y,color="green",marker="*",linestyle='dashed')
plt.title("line plot")
plt.subplot(3,2,2)
plt.scatter(x,y)
plt.title("Scatter plot")
plt.subplot(3,2,3)
plt.plot(x,y,linewidth=3)
plt.subplot(3,2,6)
plt.plot(x,y,color="green",marker="o",linestyle='dashed')
plt.title("line plot")
plt.show()

# %% [markdown]
# # Pie Chart #discrrete variable along with representation

# %%
list=[20,30,15,10,20,5]
lbs=['FaceCream','facewash','ToothPaste','Bathing Soap','shampoo','Moisurizer']

# %%
plt.pie(list,labels=lbs)
plt.show()

# %%
#list=[20,30,15,10,20,5]
#lbs=['FaceCream','facewash','ToothPaste','Bathing Soap','shampoo','Moisurizer']

plt.pie(list,labels=lbs,autopct='%1.1f%%',radius=1.5,explode=[0,0.1,0,0,0,0.5])

plt.show()

# %% [markdown]
# # Data Plot

# %%
la='python','c++','Ruby','Java'
sizes=[50,10,5,35]
explode=(0.1,0,0,0) 
#plot
plt.pie(sizes,explode=explode,labels=la,autopct='%1.1f%%')
#Saving the plot
plt.savefig('plot.jpg')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.DataFrame({'StudyHours':[10,11.5,9,16,9.25,1,11.5,9,8.5,14.5,15.5,13.75,9,8,15.50],
 'Grade':[50,50,47,97,49,3,53,42,26,74,82,62,37,15,165]})

df
# Out:
#     StudyHours  Grade
# 0        10.00     50
# 1        11.50     50
# 2         9.00     47
# 3        16.00     97
# 4         9.25     49
# 5         1.00      3
# 6        11.50     53
# 7         9.00     42
# 8         8.50     26
# 9        14.50     74
# 10       15.50     82
# 11       13.75     62
# 12        9.00     37
# 13        8.00     15
# 14       15.50    165

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   StudyHours  15 non-null     float64
#  1   Grade       15 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 368.0 bytes

# %% [markdown]
# # Histogram

# %%
plt.hist(df['Grade'])
plt.xlabel("Grade")
plt.ylabel("Count/Frequency")
plt.title("Histogram of Grade")
plt.show()

# %% [markdown]
# # box plot

# %%
plt.boxplot(df['Grade'])
plt.title("Boxplot of Grade")
plt.show()

# %% [markdown]
# # Scatter plot

# %%
plt.scatter(df['StudyHours'],df['Grade'],color='red',marker="*",s=30)
plt.show()

# %%
x=df['StudyHours']
y=df['Grade']
plt.scatter(x,y,color="blue",marker="o",s=30)
plt.show()

# %% [markdown]
# # LinePlot

# %%
plt.plot(df['StudyHours'],df['Grade'])
plt.show()

# %%
plt.plot(df["StudyHours"],color='green',linewidth=3.0)
plt.show()

# %%
x=np.arange(6)
y=x
z=x**2
e=x**3

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,z)

# %%
plt.plot(x,e)

# %%
plt.plot(x, y)
plt.plot(x, z)
plt.plot(x, e)
plt.show()

# %%
plt.plot(x, y, label='x&y')
plt.plot(x, z, label="X&z")
plt.plot(x, e, label='x&e')
plt.legend()
plt.show()

# %%
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.legend()
plt.show()

# %%
education=['B.Tech','M.Tech','B.Sc','M.Sc']
no_of_students=[50,25,15,10]
plt.pie(no_of_students,labels=education,autopct='%1.1f%%',explode=[0,0,0.1,0])
plt.show()

# %% [markdown]
# # Bar chart

# %%
plt.bar(education,no_of_students)
plt.ylabel("no_of_students")
plt.title('SRK Students')
plt.show()

# %%
plt.barh(education,no_of_students)
plt.xlabel("no_of_students")
plt.title('SRK Students')
plt.show()

# %%
#Stacked Bar Plot

# %%
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,27]
profit=[40,20,34,12]
plt.bar(company,revenue,label="Revenue")
plt.bar(company,profit,label="Profit")
plt.legend()
plt.show()

# %%
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,27]
profit=[40,20,34,12]
xpos=np.arange(len(company))
plt.bar(xpos-0.2,revenue, width=0.4, label="Revenue")
plt.bar(xpos+0.2,profit, width=0.4, label="Profit")
plt.xticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title('ÚS Technology Stocks')
plt.legend()
plt.show()

# %%
#Program for drawing multiple bar chats on one image

# %%
ecommerce=['Snapdeal', 'Alibaba', 'Amazon', 'Flipkart']
Q1_Profit=[45,100,70,40]
Q2_Profit=[40,105,65,45]
Q3_Profit=[42,120,72,50]
Q3_Profit=[34,115,60,48]
#Creating different bar charts on one image using subplot() function.
plt.figure(figsize=(10,10))
#Creating bar charts in first cell of figure having 3 rows, 2 columns.
plt.subplot(3,2,1)
plt.bar(ecommerce, Q1_Profit)
plt.title('Quarter1 Profit')
#Creating bar charts in second cell
plt.subplot(3,2,2)
plt.bar(ecommerce, Q2_Profit)
plt.title('Quarter2 Profit')
#Creating bar charts in Third cell
plt.subplot(3,2,3)
plt.bar(ecommerce, Q3_Profit)
plt.title('Quarter3 Profit')
#Creating bar charts in sixth cell
plt.subplot(3,2,6)
plt.bar(ecommerce, Q4_Profit)
plt.title('Quarter4 Profit')
#Displaying The chart
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4820\1810306058.py in <module>
#      20 #Creating bar charts in sixth cell
#      21 plt.subplot(3,2,6)
# ---> 22 plt.bar(ecommerce, Q4_Profit)
#      23 plt.title('Quarter4 Profit')
#      24 #Displaying The chart
#
# NameError: name 'Q4_Profit' is not defined
